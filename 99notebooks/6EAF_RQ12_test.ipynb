# %%
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

import sys,os
from pathlib import Path
project_root = os.path.abspath(Path("../."))
sys.path.append(str(project_root))
from utils import RQ12_testing_utils

results_folder = str(project_root) + '/results/performance2/baselines20251213'
raw_output = str(project_root) + '/results/performance2/baselines20251213/raw_outputs.csv'
test_result_outdir = results_folder+"/RQ12_results"

if not os.path.exists(test_result_outdir):
    os.makedirs(test_result_outdir)

# %%
RQ12_testing_utils.run_RQ1_tests(raw_output,test_result_outdir)
# Out:
#                   model        metric  n  mean_close  mean_logreturn  \
# 0        baseline_ARIMA            r2  5   -3.001286       -0.001934
# 1        baseline_ARIMA  sharpe_ratio  5    0.911210        1.218299
# 2        baseline_ARIMA  total_return  5    0.066909        0.174465
# 3        baseline_ARIMA      win_rate  5    0.561404        0.580882
# 4        baseline_ARIMA  max_drawdown  5    0.016504        0.047594
# 5   baseline_BuyAndHold            r2  5   -3.537468       -0.001859
# 6   baseline_BuyAndHold  sharpe_ratio  5    0.783419        0.783419
# 7   baseline_BuyAndHold  total_return  5    0.387772        0.387772
# 8   baseline_BuyAndHold      win_rate  5    0.552910        0.552910
# 9   baseline_BuyAndHold  max_drawdown  5    0.182208        0.182208
# 10         baseline_EAF            r2  5    0.854183       -0.781048
# 11         baseline_EAF  sharpe_ratio  5    1.193312        1.276808
# 12         baseline_EAF  total_return  5    0.362331        0.407848
# ...

# %%
RQ12_testing_utils.run_RQ2_tests(raw_output,test_result_outdir)
# Out:
#                     comparison        metric  n  mean_EAF  mean_other  \
# 0        EAF_vs_baseline_ARIMA          rmse  5  0.963337    0.920125
# 1        EAF_vs_baseline_ARIMA  sharpe_ratio  5  1.374045    0.000000
# 2        EAF_vs_baseline_ARIMA  total_return  5  0.412331    0.000000
# 3        EAF_vs_baseline_ARIMA      win_rate  5  0.577374    0.000000
# 4        EAF_vs_baseline_ARIMA  max_drawdown  5  0.091547    0.000000
# 5   EAF_vs_baseline_BuyAndHold          rmse  5  0.963337    0.920125
# 6   EAF_vs_baseline_BuyAndHold  sharpe_ratio  5  1.374045    0.916951
# 7   EAF_vs_baseline_BuyAndHold  total_return  5  0.412331    0.398305
# 8   EAF_vs_baseline_BuyAndHold      win_rate  5  0.577374    0.536000
# 9   EAF_vs_baseline_BuyAndHold  max_drawdown  5  0.091547    0.204304
# 10        EAF_vs_baseline_LGBM          rmse  5  0.963337    1.162436
# 11        EAF_vs_baseline_LGBM  sharpe_ratio  5  1.374045    1.775574
# ...
