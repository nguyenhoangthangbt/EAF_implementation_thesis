# %%
import sys,os,datetime
import pandas as pd
from pathlib import Path

project_root = os.path.abspath(Path("../."))
sys.path.append(str(project_root))
print(project_root)
from scripts import s4_baselines_eval,s5_EAF_eval
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

##################################
load_mt5_data=False
tsfresh_recompute=True
Long_allowed=True
Short_allowed=False

extra_symbols= []
base_features=['Close', 'High', 'Log_Return', 'Log_Return_change1', 'Log_Return_change2']
tsfresh_features = []
##################################

list_target_isClose=[False] # 
for target_isClose in list_target_isClose:
    features_file = f"gold_price_features_{'Close' if target_isClose else 'LogReturn'}{'_mt5' if load_mt5_data else ''}.csv"
    features_filepath=str(project_root) + f'/data/features/{features_file}'
    df_OHLCV =pd.read_csv(
        features_filepath,
        index_col=0, parse_dates=True)
    
    df_OHLCV.index.rename('Date', inplace=True)
    if 'Date' in df_OHLCV.columns:
        df_OHLCV['Date'] = pd.to_datetime(df_OHLCV['Date'])
        df_OHLCV.set_index('Date', inplace=True)
    ### Run ####
    cur_date = datetime.date.today().strftime('%Y%m%d')
    results_folder = Path(project_root) / f'results/performance2/baselines{cur_date}'
    results_folder.mkdir(parents=True, exist_ok=True)

    list_results=[]
    for GLOBAL_SEED in [10,200,3000,40000,500000]: #,200,3000,40000,500000
        print("target_isClose = ", target_isClose, " | ", "GLOBAL_SEED = ",GLOBAL_SEED)

        # baseline5_BuyAndHold= s4_baselines_eval.run5_BuyAndHold(GLOBAL_SEED,target_isClose,features_filepath,Long_allowed,Short_allowed)
        # print(baseline5_BuyAndHold)
        # with open(results_folder / f'baseline5_BuyAndHold{"Close" if target_isClose else "LogReturn"}.txt','a') as f:
        #     f.writelines(str(baseline5_BuyAndHold))

        # baseline2_ARIMA= s4_baselines_eval.run2_ARIMA(GLOBAL_SEED,target_isClose,features_filepath,Long_allowed,Short_allowed)
        # print(baseline2_ARIMA)
        # with open(results_folder / f'baseline2_ARIMA{"Close" if target_isClose else "LogReturn"}.txt','a') as f:
        #     f.writelines(str(baseline2_ARIMA))

        # baseline3_LSTM= s4_baselines_eval.run3_LSTM_scaled(GLOBAL_SEED,target_isClose,features_filepath,Long_allowed,Short_allowed,write_OHLCV_output=False)
        # print(baseline3_LSTM)
    
        # with open(results_folder / f'baseline3_LSTM{"Close" if target_isClose else "LogReturn"}.txt','a') as f:
        #     f.writelines(str(baseline3_LSTM))
            
        # baseline4_LGBM= s4_baselines_eval.run4_LGBM(GLOBAL_SEED,target_isClose,features_filepath,Long_allowed,Short_allowed)
        # print(baseline4_LGBM)
        # with open(results_folder / f'baseline4_LGBM{"Close" if target_isClose else "LogReturn"}.txt','a') as f:
        #     f.writelines(str(baseline4_LGBM))

        optuna_search=False ### to reduce running time, just load existing hyperparameters - already optimized
        baseline1_XGBM= s4_baselines_eval.run1_XGBM(GLOBAL_SEED,optuna_search,target_isClose,features_filepath,Long_allowed,Short_allowed)
        print(baseline1_XGBM)
        # with open(results_folder / f'baseline1_XGBM{"Close" if target_isClose else "LogReturn"}.txt','a') as f:
        #     f.writelines(str(baseline1_XGBM))

        list_adwin_config = ['adwin_default'] # ['adwin_Config_A','adwin_Config_B','adwin_Config_C','adwin_Config_D']
        for adwin_config  in list_adwin_config:
            EAF_metrics,final_model,drift_dates_test,X_test_eaf, y_test_eaf= s5_EAF_eval.run_adpative(GLOBAL_SEED,target_isClose,features_filepath,Long_allowed,Short_allowed,adwin_config)
            print(EAF_metrics)
            # list_results.append(EAF_metrics)
            # with open(results_folder / f'EAF_metrics_{adwin_config}_{"Close" if target_isClose else "LogReturn"}.txt','a') as f:
            #     f.writelines(str(EAF_metrics))
# Out:
# g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis
# target_isClose =  False  |  GLOBAL_SEED =  10
# Loading feature data from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis/data/features/gold_price_features_LogReturn.csv
# Preparing time series data with historical context
# Skip this Optuna search, reload existing optimized XGBM...
# Best trial: 181
# Best RMSE: 1.0375
# Best params: {'eta': 0.1253603984912289, 'max_depth': 14, 'min_child_weight': 9, 'subsample': 0.9627998293404935, 'colsample_bytree': 0.5803994638304243, 'lambda': 1.5940755954549102, 'alpha': 96.00826601708567}
# Model saved to g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis\models\trained\xgboost_model_LogReturn10.json
# Optuna study results saved to g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis\models\trained\optuna_study_LogReturn20251214_000604.csv
# Model training completed successfully
# Loading feature data from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis/data/features/gold_price_features_LogReturn.csv
# Preparing time series data with historical context
# [{'GLOBAL_SEED': 10, 'baseline_modelName': 'baseline_XGBM', 'target_isClose': False, 'period': 'training', 'rmse': 1.1482736352678895, 'mae': 0.8048040334898613, 'r2': 0.06772929778577363, 'strategy_name': 'baseline_XGBM', 'strategy_type': 'moc', 'n_days': 3262, 'trading_days': 2062, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.6321275291232373, 'win_days': 1293, 'win_rate': 0.6270611057225994, 'compound_gross_return': 1471.312467006698, 'total_return': 7.42171486185237, 'annualized_return': 0.7568642137681032, 'cagr': 0.7549754954199959, 'sharpe_ratio': 4.205784707575278, 'sortino_ratio': 4.3807762055907915, 'omega_ratio': 2.6414491971017076, 'max_drawdown': 0.09231037304945013, 'calmar_ratio': 8.199124202029337, 'profit_factor': 2.6414491971017076, 'volatility': 0.13632446798465758, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:06:05.220558'}, {'GLOBAL_SEED': 10, 'baseline_modelName': 'baseline_XGBM', 'target_isClose': False, 'period': 'validating', 'rmse': 1.0401547564758655, 'mae': 0.7080445059163258, 'r2': 0.0002199461607893527, 'strategy_name': 'baseline_XGBM', 'strategy_type': 'moc', 'n_days': 757, 'trading_days': 441, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.582562747688243, 'win_days': 242, 'win_rate': 0.5487528344671202, 'compound_gross_return': 0.2694664494409795, 'total_return': 0.2587000564932044, 'annualized_return': 0.08266670476705507, 'cagr': 0.08291822108664038, 'sharpe_ratio': 0.7438725161696188, 'sortino_ratio': 0.552693517240653, 'omega_ratio': 1.194432052018723, 'max_drawdown': 0.13765865683468012, 'calmar_ratio': 0.6005194781635337, 'profit_factor': 1.194432052018723, 'volatility': 0.11577176961436686, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:06:05.270179'}, {'GLOBAL_SEED': 10, 'baseline_modelName': 'baseline_XGBM', 'target_isClose': False, 'period': 'testing', 'rmse': 0.9219211193493502, 'mae': 0.6973731342819376, 'r2': -0.006811966106175182, 'strategy_name': 'baseline_XGBM', 'strategy_type': 'moc', 'n_days': 751, 'trading_days': 333, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.4434087882822903, 'win_days': 182, 'win_rate': 0.5465465465465466, 'compound_gross_return': 0.3202440741363808, 'total_return': 0.28992158670090085, 'annualized_return': 0.09770549716940091, 'cagr': 0.09765879417272982, 'sharpe_ratio': 1.0804767234124601, 'sortino_ratio': 0.735923086815431, 'omega_ratio': 1.3053924875968963, 'max_drawdown': 0.10597353596658124, 'calmar_ratio': 0.9219801555004482, 'profit_factor': 1.3053924875968963, 'volatility': 0.09003797962684332, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:06:05.312173'}]
# Run EAF evaluation ...
# drift_config = adwin_default
#  {'delta': 1.0, 'clock': 16, 'retrain_window': '126D'}
# Loading feature data from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis/data/features/gold_price_features_LogReturn.csv
# Preparing time series data with historical context
# Loading model from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis\models\trained\xgboost_model_LogReturn10.json
# Initializing ADWIN with delta=1.0, clock=16
# Preparing retraining data up to 2006-03-21 00:00:00 with window 126D
# Retraining model using data up to 2006-03-21 00:00:00
# Preparing retraining data up to 2006-11-06 00:00:00 with window 126D
# Retraining model using data up to 2006-11-06 00:00:00
# Preparing retraining data up to 2008-05-19 00:00:00 with window 126D
# Retraining model using data up to 2008-05-19 00:00:00
# Preparing retraining data up to 2008-10-03 00:00:00 with window 126D
# Retraining model using data up to 2008-10-03 00:00:00
# Preparing retraining data up to 2009-08-25 00:00:00 with window 126D
# Retraining model using data up to 2009-08-25 00:00:00
# Preparing retraining data up to 2010-11-08 00:00:00 with window 126D
# Retraining model using data up to 2010-11-08 00:00:00
# Preparing retraining data up to 2011-08-12 00:00:00 with window 126D
# Retraining model using data up to 2011-08-12 00:00:00
# Preparing retraining data up to 2012-01-24 00:00:00 with window 126D
# Retraining model using data up to 2012-01-24 00:00:00
# Preparing retraining data up to 2012-07-26 00:00:00 with window 126D
# Retraining model using data up to 2012-07-26 00:00:00
# Preparing retraining data up to 2013-05-28 00:00:00 with window 126D
# Retraining model using data up to 2013-05-28 00:00:00
# Preparing retraining data up to 2013-11-04 00:00:00 with window 126D
# Retraining model using data up to 2013-11-04 00:00:00
# Preparing retraining data up to 2014-07-18 00:00:00 with window 126D
# Retraining model using data up to 2014-07-18 00:00:00
# Preparing retraining data up to 2015-02-12 00:00:00 with window 126D
# Retraining model using data up to 2015-02-12 00:00:00
# training  - drift dates:
#  [Timestamp('2006-03-21 00:00:00'), Timestamp('2006-11-06 00:00:00'), Timestamp('2008-05-19 00:00:00'), Timestamp('2008-10-03 00:00:00'), Timestamp('2009-08-25 00:00:00'), Timestamp('2010-11-08 00:00:00'), Timestamp('2011-08-12 00:00:00'), Timestamp('2012-01-24 00:00:00'), Timestamp('2012-07-26 00:00:00'), Timestamp('2013-05-28 00:00:00'), Timestamp('2013-11-04 00:00:00'), Timestamp('2014-07-18 00:00:00'), Timestamp('2015-02-12 00:00:00')]
# Initializing ADWIN with delta=1.0, clock=16
# Preparing retraining data up to 2019-10-04 00:00:00 with window 126D
# Retraining model using data up to 2019-10-04 00:00:00
# Preparing retraining data up to 2019-12-12 00:00:00 with window 126D
# Retraining model using data up to 2019-12-12 00:00:00
# Preparing retraining data up to 2020-03-17 00:00:00 with window 126D
# Retraining model using data up to 2020-03-17 00:00:00
# Preparing retraining data up to 2020-06-17 00:00:00 with window 126D
# Retraining model using data up to 2020-06-17 00:00:00
# Preparing retraining data up to 2020-11-24 00:00:00 with window 126D
# Retraining model using data up to 2020-11-24 00:00:00
# Preparing retraining data up to 2021-04-15 00:00:00 with window 126D
# Retraining model using data up to 2021-04-15 00:00:00
# validating  - drift dates:
#  [Timestamp('2019-10-04 00:00:00'), Timestamp('2019-12-12 00:00:00'), Timestamp('2020-03-17 00:00:00'), Timestamp('2020-06-17 00:00:00'), Timestamp('2020-11-24 00:00:00'), Timestamp('2021-04-15 00:00:00')]
# Initializing ADWIN with delta=1.0, clock=16
# Preparing retraining data up to 2022-08-22 00:00:00 with window 126D
# Retraining model using data up to 2022-08-22 00:00:00
# Preparing retraining data up to 2023-08-29 00:00:00 with window 126D
# Retraining model using data up to 2023-08-29 00:00:00
# Preparing retraining data up to 2024-08-13 00:00:00 with window 126D
# Retraining model using data up to 2024-08-13 00:00:00
# testing  - drift dates:
#  [Timestamp('2022-08-22 00:00:00'), Timestamp('2023-08-29 00:00:00'), Timestamp('2024-08-13 00:00:00')]
# [{'GLOBAL_SEED': 10, 'baseline_modelName': 'baseline_EAF', 'target_isClose': False, 'period': 'training', 'rmse': 1.5702136557866933, 'mae': 1.1223798170876322, 'r2': -0.7432864292960073, 'strategy_name': 'EAF', 'strategy_type': 'moc', 'n_days': 3262, 'trading_days': 1609, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.49325567136725934, 'win_days': 845, 'win_rate': 0.5251709136109385, 'compound_gross_return': 1.1384462182274082, 'total_return': 0.8719837932015551, 'annualized_return': 0.06047676776270361, 'cagr': 0.060357918215400375, 'sharpe_ratio': 0.5121016895277766, 'sortino_ratio': 0.36031063905851957, 'omega_ratio': 1.1371954538231126, 'max_drawdown': 0.28207342469849883, 'calmar_ratio': 0.21440079946328053, 'profit_factor': 1.1371954538231126, 'volatility': 0.1315433169176281, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:08:09.310908'}, {'GLOBAL_SEED': 10, 'baseline_modelName': 'baseline_EAF', 'target_isClose': False, 'period': 'validating', 'rmse': 1.4323294407819216, 'mae': 0.9581566008174127, 'r2': -0.8958081535124955, 'strategy_name': 'EAF', 'strategy_type': 'moc', 'n_days': 757, 'trading_days': 385, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.5085865257595773, 'win_days': 221, 'win_rate': 0.574025974025974, 'compound_gross_return': 0.25259509714504813, 'total_return': 0.2393923685247027, 'annualized_return': 0.07785539467698421, 'cagr': 0.07809175072907282, 'sharpe_ratio': 0.8226662819307484, 'sortino_ratio': 0.5177701401603385, 'omega_ratio': 1.2310474369376274, 'max_drawdown': 0.1349416567245279, 'calmar_ratio': 0.5769559716901912, 'profit_factor': 1.2310474369376274, 'volatility': 0.09687043843832172, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:08:39.190156'}, {'GLOBAL_SEED': 10, 'baseline_modelName': 'baseline_EAF', 'target_isClose': False, 'period': 'testing', 'rmse': 1.019400040077446, 'mae': 0.7865798033915326, 'r2': -0.23097755247948815, 'strategy_name': 'EAF', 'strategy_type': 'moc', 'n_days': 751, 'trading_days': 338, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.45006657789613846, 'win_days': 183, 'win_rate': 0.5414201183431953, 'compound_gross_return': 0.2202888486058372, 'total_return': 0.21436587720043654, 'annualized_return': 0.0690862999502646, 'cagr': 0.06905370425456647, 'sharpe_ratio': 0.7106265712614696, 'sortino_ratio': 0.46835542763552135, 'omega_ratio': 1.196765484304561, 'max_drawdown': 0.11206041400763753, 'calmar_ratio': 0.616509412017307, 'profit_factor': 1.196765484304561, 'volatility': 0.10122197735451019, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:09:08.138351'}]
# target_isClose =  False  |  GLOBAL_SEED =  200
# Loading feature data from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis/data/features/gold_price_features_LogReturn.csv
# Preparing time series data with historical context
# Skip this Optuna search, reload existing optimized XGBM...
# Best trial: 159
# Best RMSE: 1.0395
# Best params: {'eta': 0.02275260071007695, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.5158689172955878, 'colsample_bytree': 0.8004311157680741, 'lambda': 14.893021446546435, 'alpha': 99.57801035172672}
# Model saved to g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis\models\trained\xgboost_model_LogReturn200.json
# Optuna study results saved to g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis\models\trained\optuna_study_LogReturn20251214_000910.csv
# Model training completed successfully
# Loading feature data from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis/data/features/gold_price_features_LogReturn.csv
# Preparing time series data with historical context
# [{'GLOBAL_SEED': 200, 'baseline_modelName': 'baseline_XGBM', 'target_isClose': False, 'period': 'training', 'rmse': 1.1733768009754626, 'mae': 0.8221342430052486, 'r2': 0.02652176885297297, 'strategy_name': 'baseline_XGBM', 'strategy_type': 'moc', 'n_days': 3262, 'trading_days': 2347, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.7194972409564684, 'win_days': 1368, 'win_rate': 0.5828717511717085, 'compound_gross_return': 284.04231950598023, 'total_return': 5.7983361021012785, 'annualized_return': 0.5475676717150075, 'cagr': 0.5462782900056724, 'sharpe_ratio': 3.026625933393486, 'sortino_ratio': 2.969686900212621, 'omega_ratio': 1.8995580552422375, 'max_drawdown': 0.13750764110352617, 'calmar_ratio': 3.9820890484388216, 'profit_factor': 1.8995580552422375, 'volatility': 0.14799983146813575, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:09:10.448937'}, {'GLOBAL_SEED': 200, 'baseline_modelName': 'baseline_XGBM', 'target_isClose': False, 'period': 'validating', 'rmse': 1.0393591807511344, 'mae': 0.708029490003762, 'r2': 0.0017487505040250095, 'strategy_name': 'baseline_XGBM', 'strategy_type': 'moc', 'n_days': 757, 'trading_days': 448, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.5918097754293263, 'win_days': 249, 'win_rate': 0.5558035714285714, 'compound_gross_return': 0.4257357241661115, 'total_return': 0.3738905252736301, 'annualized_return': 0.12532641995314742, 'cagr': 0.1257150680042045, 'sharpe_ratio': 1.1025317954744802, 'sortino_ratio': 0.8220778988120444, 'omega_ratio': 1.2986730438760243, 'max_drawdown': 0.10519670454298741, 'calmar_ratio': 1.1913530989170316, 'profit_factor': 1.2986730438760243, 'volatility': 0.11289065643901842, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:09:10.498587'}, {'GLOBAL_SEED': 200, 'baseline_modelName': 'baseline_XGBM', 'target_isClose': False, 'period': 'testing', 'rmse': 0.9190837477074716, 'mae': 0.6962325964544614, 'r2': -0.0006242268998239986, 'strategy_name': 'baseline_XGBM', 'strategy_type': 'moc', 'n_days': 751, 'trading_days': 334, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.4447403462050599, 'win_days': 194, 'win_rate': 0.5808383233532934, 'compound_gross_return': 0.635808908218723, 'total_return': 0.5053582350011762, 'annualized_return': 0.17955587618267876, 'cagr': 0.17946697685747015, 'sharpe_ratio': 1.80849148622475, 'sortino_ratio': 1.2525635198329794, 'omega_ratio': 1.5836618795655752, 'max_drawdown': 0.0932867628602821, 'calmar_ratio': 1.9247733620214054, 'profit_factor': 1.5836618795655752, 'volatility': 0.09376558818668726, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:09:10.546507'}]
# Run EAF evaluation ...
# drift_config = adwin_default
#  {'delta': 1.0, 'clock': 16, 'retrain_window': '126D'}
# Loading feature data from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis/data/features/gold_price_features_LogReturn.csv
# Preparing time series data with historical context
# Loading model from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis\models\trained\xgboost_model_LogReturn200.json
# Initializing ADWIN with delta=1.0, clock=16
# Preparing retraining data up to 2006-03-21 00:00:00 with window 126D
# Retraining model using data up to 2006-03-21 00:00:00
# Preparing retraining data up to 2006-11-06 00:00:00 with window 126D
# Retraining model using data up to 2006-11-06 00:00:00
# Preparing retraining data up to 2008-05-19 00:00:00 with window 126D
# Retraining model using data up to 2008-05-19 00:00:00
# Preparing retraining data up to 2008-10-03 00:00:00 with window 126D
# Retraining model using data up to 2008-10-03 00:00:00
# Preparing retraining data up to 2009-08-25 00:00:00 with window 126D
# Retraining model using data up to 2009-08-25 00:00:00
# Preparing retraining data up to 2010-11-08 00:00:00 with window 126D
# Retraining model using data up to 2010-11-08 00:00:00
# Preparing retraining data up to 2011-08-12 00:00:00 with window 126D
# Retraining model using data up to 2011-08-12 00:00:00
# Preparing retraining data up to 2012-01-24 00:00:00 with window 126D
# Retraining model using data up to 2012-01-24 00:00:00
# Preparing retraining data up to 2012-07-26 00:00:00 with window 126D
# Retraining model using data up to 2012-07-26 00:00:00
# Preparing retraining data up to 2013-05-28 00:00:00 with window 126D
# Retraining model using data up to 2013-05-28 00:00:00
# Preparing retraining data up to 2013-11-04 00:00:00 with window 126D
# Retraining model using data up to 2013-11-04 00:00:00
# Preparing retraining data up to 2014-07-18 00:00:00 with window 126D
# Retraining model using data up to 2014-07-18 00:00:00
# Preparing retraining data up to 2015-02-12 00:00:00 with window 126D
# Retraining model using data up to 2015-02-12 00:00:00
# training  - drift dates:
#  [Timestamp('2006-03-21 00:00:00'), Timestamp('2006-11-06 00:00:00'), Timestamp('2008-05-19 00:00:00'), Timestamp('2008-10-03 00:00:00'), Timestamp('2009-08-25 00:00:00'), Timestamp('2010-11-08 00:00:00'), Timestamp('2011-08-12 00:00:00'), Timestamp('2012-01-24 00:00:00'), Timestamp('2012-07-26 00:00:00'), Timestamp('2013-05-28 00:00:00'), Timestamp('2013-11-04 00:00:00'), Timestamp('2014-07-18 00:00:00'), Timestamp('2015-02-12 00:00:00')]
# Initializing ADWIN with delta=1.0, clock=16
# Preparing retraining data up to 2019-10-04 00:00:00 with window 126D
# Retraining model using data up to 2019-10-04 00:00:00
# Preparing retraining data up to 2019-12-12 00:00:00 with window 126D
# Retraining model using data up to 2019-12-12 00:00:00
# Preparing retraining data up to 2020-03-17 00:00:00 with window 126D
# Retraining model using data up to 2020-03-17 00:00:00
# Preparing retraining data up to 2020-06-17 00:00:00 with window 126D
# Retraining model using data up to 2020-06-17 00:00:00
# Preparing retraining data up to 2020-11-24 00:00:00 with window 126D
# Retraining model using data up to 2020-11-24 00:00:00
# Preparing retraining data up to 2021-04-15 00:00:00 with window 126D
# Retraining model using data up to 2021-04-15 00:00:00
# validating  - drift dates:
#  [Timestamp('2019-10-04 00:00:00'), Timestamp('2019-12-12 00:00:00'), Timestamp('2020-03-17 00:00:00'), Timestamp('2020-06-17 00:00:00'), Timestamp('2020-11-24 00:00:00'), Timestamp('2021-04-15 00:00:00')]
# Initializing ADWIN with delta=1.0, clock=16
# Preparing retraining data up to 2022-08-22 00:00:00 with window 126D
# Retraining model using data up to 2022-08-22 00:00:00
# Preparing retraining data up to 2023-08-29 00:00:00 with window 126D
# Retraining model using data up to 2023-08-29 00:00:00
# Preparing retraining data up to 2024-08-13 00:00:00 with window 126D
# Retraining model using data up to 2024-08-13 00:00:00
# testing  - drift dates:
#  [Timestamp('2022-08-22 00:00:00'), Timestamp('2023-08-29 00:00:00'), Timestamp('2024-08-13 00:00:00')]
# [{'GLOBAL_SEED': 200, 'baseline_modelName': 'baseline_EAF', 'target_isClose': False, 'period': 'training', 'rmse': 1.570504131017625, 'mae': 1.1226930604227987, 'r2': -0.7439314731908302, 'strategy_name': 'EAF', 'strategy_type': 'moc', 'n_days': 3262, 'trading_days': 1611, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.493868792152054, 'win_days': 845, 'win_rate': 0.5245189323401613, 'compound_gross_return': 1.0458097781430933, 'total_return': 0.8281967828302996, 'annualized_return': 0.05685484134663121, 'cagr': 0.05674329843431902, 'sharpe_ratio': 0.4852983158184399, 'sortino_ratio': 0.3410820270825157, 'omega_ratio': 1.1294145511981213, 'max_drawdown': 0.2820734246984988, 'calmar_ratio': 0.2015604320307804, 'profit_factor': 1.129414551198121, 'volatility': 0.13183822250693703, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:11:10.887462'}, {'GLOBAL_SEED': 200, 'baseline_modelName': 'baseline_EAF', 'target_isClose': False, 'period': 'validating', 'rmse': 1.4321524458300305, 'mae': 0.9588120824750785, 'r2': -0.8953396471322239, 'strategy_name': 'EAF', 'strategy_type': 'moc', 'n_days': 757, 'trading_days': 403, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.5323645970937912, 'win_days': 236, 'win_rate': 0.5856079404466501, 'compound_gross_return': 0.36034698427557665, 'total_return': 0.3223010961512709, 'annualized_return': 0.10787573081920221, 'cagr': 0.10820769888240123, 'sharpe_ratio': 1.0937010105855927, 'sortino_ratio': 0.7048262826654578, 'omega_ratio': 1.3099932506001148, 'max_drawdown': 0.13494165672452801, 'calmar_ratio': 0.7994249769692794, 'profit_factor': 1.3099932506001148, 'volatility': 0.09809973414752311, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:11:39.860662'}, {'GLOBAL_SEED': 200, 'baseline_modelName': 'baseline_EAF', 'target_isClose': False, 'period': 'testing', 'rmse': 1.019172477093552, 'mae': 0.786726775266332, 'r2': -0.2304280259982725, 'strategy_name': 'EAF', 'strategy_type': 'moc', 'n_days': 751, 'trading_days': 339, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.45139813581890814, 'win_days': 187, 'win_rate': 0.551622418879056, 'compound_gross_return': 0.3027601449343642, 'total_return': 0.27976311704721346, 'annualized_return': 0.09280599563732417, 'cagr': 0.09276173215585404, 'sharpe_ratio': 0.9278497200155167, 'sortino_ratio': 0.6166449121992106, 'omega_ratio': 1.2639316068510669, 'max_drawdown': 0.11206041400763744, 'calmar_ratio': 0.8281782327789633, 'profit_factor': 1.2639316068510669, 'volatility': 0.10117504841104316, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:12:07.672282'}]
# target_isClose =  False  |  GLOBAL_SEED =  3000
# Loading feature data from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis/data/features/gold_price_features_LogReturn.csv
# Preparing time series data with historical context
# Skip this Optuna search, reload existing optimized XGBM...
# Best trial: 173
# Best RMSE: 1.0394
# Best params: {'eta': 0.010873590369060705, 'max_depth': 13, 'min_child_weight': 8, 'subsample': 0.7178671324727379, 'colsample_bytree': 0.9094891902640904, 'lambda': 0.02932433501657699, 'alpha': 99.65838224384034}
# Model saved to g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis\models\trained\xgboost_model_LogReturn3000.json
# Optuna study results saved to g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis\models\trained\optuna_study_LogReturn20251214_001210.csv
# Model training completed successfully
# Loading feature data from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis/data/features/gold_price_features_LogReturn.csv
# Preparing time series data with historical context
# [{'GLOBAL_SEED': 3000, 'baseline_modelName': 'baseline_XGBM', 'target_isClose': False, 'period': 'training', 'rmse': 1.1713240245915404, 'mae': 0.8208373615265782, 'r2': 0.029924912871249876, 'strategy_name': 'baseline_XGBM', 'strategy_type': 'moc', 'n_days': 3262, 'trading_days': 2381, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.7299202942979767, 'win_days': 1386, 'win_rate': 0.5821083578328433, 'compound_gross_return': 332.8197665758643, 'total_return': 5.9580408167400565, 'annualized_return': 0.5665686407927424, 'cagr': 0.5652269694250134, 'sharpe_ratio': 3.0929097919134683, 'sortino_ratio': 3.097950849489344, 'omega_ratio': 1.9143965816519646, 'max_drawdown': 0.13750764110352634, 'calmar_ratio': 4.120270235500483, 'profit_factor': 1.9143965816519646, 'volatility': 0.14881708885902672, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:12:10.366352'}, {'GLOBAL_SEED': 3000, 'baseline_modelName': 'baseline_XGBM', 'target_isClose': False, 'period': 'validating', 'rmse': 1.0396974661530671, 'mae': 0.7081842790697436, 'r2': 0.0010988331571342158, 'strategy_name': 'baseline_XGBM', 'strategy_type': 'moc', 'n_days': 757, 'trading_days': 494, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.6525759577278731, 'win_days': 273, 'win_rate': 0.5526315789473685, 'compound_gross_return': 0.40845269523549455, 'total_return': 0.3670789612989581, 'annualized_return': 0.12076680296283904, 'cagr': 0.12114056421011754, 'sharpe_ratio': 0.9558111504680034, 'sortino_ratio': 0.7469950746945895, 'omega_ratio': 1.2462303412248152, 'max_drawdown': 0.11535065691977314, 'calmar_ratio': 1.0469537511765785, 'profit_factor': 1.2462303412248152, 'volatility': 0.12784744781325086, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:12:10.417262'}, {'GLOBAL_SEED': 3000, 'baseline_modelName': 'baseline_XGBM', 'target_isClose': False, 'period': 'testing', 'rmse': 0.9185046164975378, 'mae': 0.6948471541954956, 'r2': 0.0006363984703078307, 'strategy_name': 'baseline_XGBM', 'strategy_type': 'moc', 'n_days': 751, 'trading_days': 407, 'skipped_trades': 0, 'gap_skips': 0, 'edge_skips': 0, 'trade_rate': 0.5419440745672437, 'win_days': 235, 'win_rate': 0.5773955773955773, 'compound_gross_return': 0.5974072237981791, 'total_return': 0.48552616847215435, 'annualized_return': 0.17019071421844245, 'cagr': 0.170106777685205, 'sharpe_ratio': 1.5243708344281188, 'sortino_ratio': 1.098102779105259, 'omega_ratio': 1.4110651586874978, 'max_drawdown': 0.07514909838478905, 'calmar_ratio': 2.264707333506623, 'profit_factor': 1.4110651586874978, 'volatility': 0.10687659645434898, 'risk_free_rate': 0.0, 'execution_threshold': 0.0, 'max_gap': 0.02, 'at': '2025-12-14 00:12:10.468768'}]
# Run EAF evaluation ...
# drift_config = adwin_default
#  {'delta': 1.0, 'clock': 16, 'retrain_window': '126D'}
# Loading feature data from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis/data/features/gold_price_features_LogReturn.csv
# Preparing time series data with historical context
# Loading model from g:\My Drive\0Study_programs\1Msc_ML_AI\EAF_python_project\EAF_implementation_thesis\models\trained\xgboost_model_LogReturn3000.json
# Initializing ADWIN with delta=1.0, clock=16
# Preparing retraining data up to 2006-03-21 00:00:00 with window 126D
# Retraining model using data up to 2006-03-21 00:00:00
# Preparing retraining data up to 2006-11-06 00:00:00 with window 126D
# Retraining model using data up to 2006-11-06 00:00:00
# Preparing retraining data up to 2008-05-19 00:00:00 with window 126D
# Retraining model using data up to 2008-05-19 00:00:00
# Preparing retraining data up to 2008-10-03 00:00:00 with window 126D
# Retraining model using data up to 2008-10-03 00:00:00
# Preparing retraining data up to 2009-08-25 00:00:00 with window 126D
# Retraining model using data up to 2009-08-25 00:00:00
# Preparing retraining data up to 2010-11-08 00:00:00 with window 126D
# Retraining model using data up to 2010-11-08 00:00:00
# Preparing retraining data up to 2011-08-12 00:00:00 with window 126D
# Retraining model using data up to 2011-08-12 00:00:00
# Preparing retraining data up to 2012-01-24 00:00:00 with window 126D
# Retraining model using data up to 2012-01-24 00:00:00
# Preparing retraining data up to 2012-07-26 00:00:00 with window 126D
# Retraining model using data up to 2012-07-26 00:00:00
# Preparing retraining data up to 2013-05-28 00:00:00 with window 126D
# Retraining model using data up to 2013-05-28 00:00:00
# Preparing retraining data up to 2013-11-04 00:00:00 with window 126D
# Retraining model using data up to 2013-11-04 00:00:00
# Preparing retraining data up to 2014-07-18 00:00:00 with window 126D
# Retraining model using data up to 2014-07-18 00:00:00
# Preparing retraining data up to 2015-02-12 00:00:00 with window 126D
# Retraining model using data up to 2015-02-12 00:00:00
# training  - drift dates:
#  [Timestamp('2006-03-21 00:00:00'), Timestamp('2006-11-06 00:00:00'), Timestamp('2008-05-19 00:00:00'), Timestamp('2008-10-03 00:00:00'), Timestamp('2009-08-25 00:00:00'), Timestamp('2010-11-08 00:00:00'), Timestamp('2011-08-12 00:00:00'), Timestamp('2012-01-24 00:00:00'), Timestamp('2012-07-26 00:00:00'), Timestamp('2013-05-28 00:00:00'), Timestamp('2013-11-04 00:00:00'), Timestamp('2014-07-18 00:00:00'), Timestamp('2015-02-12 00:00:00')]
# Initializing ADWIN with delta=1.0, clock=16
# Preparing retraining data up to 2019-10-04 00:00:00 with window 126D
# Retraining model using data up to 2019-10-04 00:00:00
# Preparing retraining data up to 2019-12-12 00:00:00 with window 126D
# Retraining model using data up to 2019-12-12 00:00:00
# Preparing retraining data up to 2020-03-17 00:00:00 with window 126D
# Retraining model using data up to 2020-03-17 00:00:00
# Preparing retraining data up to 2020-06-17 00:00:00 with window 126D
# Retraining model using data up to 2020-06-17 00:00:00
# Preparing retraining data up to 2020-11-24 00:00:00 with window 126D
# Retraining model using data up to 2020-11-24 00:00:00
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
